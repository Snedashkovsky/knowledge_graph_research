# %% [markdown]
# # Upload Knowledge Graph to Bostrom network

# %%
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
from IPython.display import HTML, display

from config import ipfs_client
from src.utils_cyber import create_cls
# Out:
# /Users/sergenedashkovsky/Library/Python/3.8/lib/python/site-packages/ipfshttpclient/client/__init__.py:75: VersionMismatch: Unsupported daemon version '0.10.0' (not in range: 0.5.0 ≤ … < 0.9.0)
#   warnings.warn(exceptions.VersionMismatch(version, minimum, maximum))

# %% [markdown]
# ## Read and Preprocess Ontology Data

# %%
def read_and_preprocess_ontology(ontology_file_name: str, show_aggregations: bool = True):
    _ontology_df = pd.read_csv(ontology_file_name, sep=';')
    display(HTML(_ontology_df.head(50).to_html(index=False)))

    _ontology_df["subject"] = _ontology_df["subject"].map(
        lambda x: x.replace('_', ' ').lower().split(' (')[0].split(',')[0])
    _ontology_df["object"] = _ontology_df["object"].map(
        lambda x: x.replace('_', ' ').lower().split(' (')[0].split(',')[0])
    _subject_object_list = set(list(_ontology_df["subject"]) + list(_ontology_df["object"]))
    print(f'Number of items: {len(_subject_object_list):>,}')
    print(f'Number of links: {len(_ontology_df):>,}')

    if show_aggregations:
        print('\nTop subjects')
        display(HTML(
            _ontology_df.groupby('subject')['object']
                .agg(np.count_nonzero).reset_index().sort_values('object', ascending=False).head(10)
                .to_html(index=False)))

        print('\nTop objects')
        display(HTML(
            _ontology_df.groupby('object')['subject']
                .agg(np.count_nonzero).reset_index().sort_values('subject', ascending=False).head(10)
                .to_html(index=False)))

    print('\nUpload CIDs to IPFS')
    ipfs_hashes_dict = {name: ipfs_client.add_str(name) for name in tqdm(_subject_object_list)}
    _ontology_df.loc[:, 'subject_ipfs_hash'] = _ontology_df['subject'].map(lambda x: ipfs_hashes_dict[x])
    _ontology_df.loc[:, 'object_ipfs_hash'] = _ontology_df['object'].map(lambda x: ipfs_hashes_dict[x])

    return _ontology_df

# %%
ontology_df = read_and_preprocess_ontology(ontology_file_name='data/caligraph-ontology.nt.csv')
ontology_df.to_csv('data/dbpedia_caligraph_relations_for_upload.csv')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>subject</th>
#       <th>object</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1970s_event</td>
#       <td>Class</td>
#     </tr>
#     <tr>
#       <td>1970s_event</td>
#       <td>Event</td>
#     </tr>
#     <tr>
#       <td>1980s_event</td>
#       <td>Class</td>
#     </tr>
#     <tr>
#       <td>1980s_event</td>
#       <td>Event</td>
#     </tr>
#     <tr>
#       <td>1990s_event</td>
#       <td>Class</td>
#     </tr>
#     <tr>
#       <td>1990s_event</td>
#       <td>Event</td>
#     </tr>
#     <tr>
#       <td>19th-century_maritime_incident</td>
#       <td>Class</td>
#     </tr>
#     <tr>
#       <td>19th-century_maritime_incident</td>
#       <td>Maritime_incident</td>
#     </tr>
#     <tr>
#       <td>19th-century_person</td>
#       <td>2nd-millennium_person</td>
#     </tr>
#     <tr>
#       <td>19th-century_person</td>
#       <td>Class</td>
#     </tr>
#     <tr>
#       <td>19th-century_person</td>
#       <td>Modern_person</td>
#     </tr>
#     <tr>
#       <td>1st-millennium_birth</td>
#       <td>Birth</td>
#     </tr>
#     <tr>
#       <td>1st-millennium_birth</td>
#       <td>Class</td>
#     </tr>
#     <tr>
#       <td>1st-millennium_death</td>
#       <td>Class</td>
#     </tr>
#     <tr>
#       <td>1st-millennium_death</td>
#       <td>Death</td>
#     </tr>
#     <tr>
#       <td>2000s_event</td>
#       <td>Class</td>
#     </tr>
#     <tr>
#       <td>2000s_event</td>
#       <td>Event</td>
#     </tr>
#     <tr>
#       <td>2010s_event</td>
#       <td>Class</td>
#     </tr>
#     <tr>
#       <td>2010s_event</td>
#       <td>Event</td>
#     </tr>
#     <tr>
#       <td>20th-century_European_person</td>
#       <td>20th-century_person</td>
#     </tr>
#     <tr>
#       <td>20th-century_European_person</td>
#       <td>Class</td>
#     </tr>
#     <tr>
#       <td>20th-century_person</td>
#       <td>2nd-millennium_person</td>
#     </tr>
#     <tr>
#       <td>20th-century_person</td>
#       <td>Class</td>
#     </tr>
#     <tr>
#       <td>20th-century_person</td>
#       <td>Modern_person</td>
#     </tr>
#     <tr>
#       <td>20th-century_writer</td>
#       <td>20th-century_person</td>
#     </tr>
#     <tr>
#       <td>20th-century_writer</td>
#       <td>Class</td>
#     </tr>
#     <tr>
#       <td>20th-century_writer</td>
#       <td>Writer</td>
#     </tr>
#     <tr>
#       <td>21st-century_person</td>
#       <td>Class</td>
#     </tr>
#     <tr>
#       <td>21st-century_person</td>
#       <td>Modern_person</td>
#     </tr>
#     <tr>
#       <td>21st-century_writer</td>
#       <td>21st-century_person</td>
#     </tr>
#     <tr>
#       <td>21st-century_writer</td>
#       <td>Class</td>
#     </tr>
#     <tr>
#       <td>21st-century_writer</td>
#       <td>Writer</td>
#     </tr>
#     <tr>
#       <td>2nd-millennium_birth</td>
#       <td>Birth</td>
#     </tr>
#     <tr>
#       <td>2nd-millennium_birth</td>
#       <td>Class</td>
#     </tr>
#     <tr>
#       <td>2nd-millennium_conflict</td>
#       <td>Class</td>
#     </tr>
#     <tr>
#       <td>2nd-millennium_conflict</td>
#       <td>Conflict</td>
#     </tr>
#     <tr>
#       <td>2nd-millennium_death</td>
#       <td>Class</td>
#     </tr>
#     <tr>
#       <td>2nd-millennium_death</td>
#       <td>Death</td>
#     </tr>
#     <tr>
#       <td>2nd-millennium_disestablishment</td>
#       <td>Class</td>
#     </tr>
#     <tr>
#       <td>2nd-millennium_disestablishment</td>
#       <td>Disestablishment</td>
#     </tr>
#     <tr>
#       <td>2nd-millennium_establishment</td>
#       <td>Class</td>
#     </tr>
#     <tr>
#       <td>2nd-millennium_establishment</td>
#       <td>Establishment</td>
#     </tr>
#     <tr>
#       <td>2nd-millennium_person</td>
#       <td>Class</td>
#     </tr>
#     <tr>
#       <td>2nd-millennium_person</td>
#       <td>Person</td>
#     </tr>
#     <tr>
#       <td>Academic</td>
#       <td>Class</td>
#     </tr>
#     <tr>
#       <td>Academic</td>
#       <td>Educator</td>
#     </tr>
#     <tr>
#       <td>Academic</td>
#       <td>Scholar_or_academic</td>
#     </tr>
#     <tr>
#       <td>Academic</td>
#       <td>University_and_college_person</td>
#     </tr>
#     <tr>
#       <td>Academic_institution</td>
#       <td>Academic_organization</td>
#     </tr>
#     <tr>
#       <td>Academic_institution</td>
#       <td>Class</td>
#     </tr>
#   </tbody>
# </table>
# Number of items: 1,349
# Number of links: 6,130
#
# Top subjects
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>subject</th>
#       <th>object</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>artist</td>
#       <td>50</td>
#     </tr>
#     <tr>
#       <td>badminton player</td>
#       <td>47</td>
#     </tr>
#     <tr>
#       <td>ambassador</td>
#       <td>45</td>
#     </tr>
#     <tr>
#       <td>academic journal</td>
#       <td>43</td>
#     </tr>
#     <tr>
#       <td>body of water</td>
#       <td>42</td>
#     </tr>
#     <tr>
#       <td>airport</td>
#       <td>42</td>
#     </tr>
#     <tr>
#       <td>airline</td>
#       <td>41</td>
#     </tr>
#     <tr>
#       <td>bank</td>
#       <td>40</td>
#     </tr>
#     <tr>
#       <td>album</td>
#       <td>39</td>
#     </tr>
#     <tr>
#       <td>baseball player</td>
#       <td>38</td>
#     </tr>
#   </tbody>
# </table>
# Top objects
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>object</th>
#       <th>subject</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>class</td>
#       <td>1206</td>
#     </tr>
#     <tr>
#       <td>work</td>
#       <td>189</td>
#     </tr>
#     <tr>
#       <td>unit of work</td>
#       <td>187</td>
#     </tr>
#     <tr>
#       <td>topical concept</td>
#       <td>183</td>
#     </tr>
#     <tr>
#       <td>time period</td>
#       <td>176</td>
#     </tr>
#     <tr>
#       <td>specie</td>
#       <td>157</td>
#     </tr>
#     <tr>
#       <td>sports season</td>
#       <td>157</td>
#     </tr>
#     <tr>
#       <td>thing</td>
#       <td>127</td>
#     </tr>
#     <tr>
#       <td>results of a sport competition</td>
#       <td>112</td>
#     </tr>
#     <tr>
#       <td>person function</td>
#       <td>111</td>
#     </tr>
#   </tbody>
# </table>
# Upload CIDs to IPFS
#   0%|          | 0/1349 [00:00<?, ?it/s]

# %% [markdown]
# ## Create cyberlinks

# %%
link_candidates = ontology_df[['subject_ipfs_hash', 'object_ipfs_hash']].values.tolist()
link_candidates = link_candidates[80:400]
link_candidates[:5]
# Out:
# [['QmTYZZkRC8Kh4Uj3NhbMTbsHtn4GUFnKfMfKVU5BiMJHob',
#   'QmPeLePmoiUViajVjay7CiqDXRL8BcYHXnW99yBKN1uLi2'],
#  ['QmTYZZkRC8Kh4Uj3NhbMTbsHtn4GUFnKfMfKVU5BiMJHob',
#   'QmUveVbC1JdAJE4W53BwGFLJ5e2VkMKX5HB8MZ7TLBKkEy'],
#  ['QmTYZZkRC8Kh4Uj3NhbMTbsHtn4GUFnKfMfKVU5BiMJHob',
#   'QmPWVLevpzEki6bcBF7bEk7rrNRhFSnBXD4imtTYM2pAgA'],
#  ['QmTYZZkRC8Kh4Uj3NhbMTbsHtn4GUFnKfMfKVU5BiMJHob',
#   'QmSpPA6mVdwq41xLBtgoHsi1ZrTn7DSi8kvNX9crhzDRFm'],
#  ['QmTYZZkRC8Kh4Uj3NhbMTbsHtn4GUFnKfMfKVU5BiMJHob',
#   'QmWWcKFcfXMNQGGUrymVMm973SudGmeLGeVsZGCoQQaG4r']]

# %%
NUMBER_CYBERLINK_IN_TX = 50

link_candidates_chunks = [link_candidates[i: i+ NUMBER_CYBERLINK_IN_TX] for i in range(0, len(link_candidates), NUMBER_CYBERLINK_IN_TX)]

res = []
for link_candidates_chunk in link_candidates_chunks:
    res.append(create_cls(link_candidates=link_candidates_chunk, print_message=True))
# Out:
# {'code': 0,
#  'codespace': '',
#  'data': None,
#  'gas_used': 1311249,
#  'gas_wanted': 2200000,
#  'height': 2366895,
#  'info': None,
#  'logs': [{'events': [{'attributes': [{'key': 'particleFrom',
#                                        'value': 'QmTYZZkRC8Kh4Uj3NhbMTbsHtn4GUFnKfMfKVU5BiMJHob'},
#                                       {'key': 'particleTo',
#                                        'value': 'QmPeLePmoiUViajVjay7CiqDXRL8BcYHXnW99yBKN1uLi2'},
#                                       {'key': 'neuron',
#                                        'value': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t'}],
#                        'type': 'cyberlink'},
#                       {'attributes': [{'key': 'action',
#                                        'value': '/cyber.graph.v1beta1.MsgCyberlink'},
#                                       {'key': 'module', 'value': 'graph'},
#                                       {'key': 'sender',
#                                        'value': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t'}],
#                        'type': 'message'}],
#            'events_by_type': {'cyberlink': {'neuron': ['bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t'],
#                                             'particleFrom': ['QmTYZZkRC8Kh4Uj3NhbMTbsHtn4GUFnKfMfKVU5BiMJHob'],
#                                             'particleTo': ['QmPeLePmoiUViajVjay7CiqDXRL8BcYHXnW99yBKN1uLi2']},
#                               'message': {'action': ['/cyber.graph.v1beta1.MsgCyberlink'],
#                                           'module': ['graph'],
#                                           'sender': ['bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t']}},
#            'log': '',
#            'msg_index': 0},
#           {'events': [{'attributes': [{'key': 'particleFrom',
#                                        'value': 'QmTYZZkRC8Kh4Uj3NhbMTbsHtn4GUFnKfMfKVU5BiMJHob'},
#                                       {'key': 'particleTo',
#                                        'value': 'QmUveVbC1JdAJE4W53BwGFLJ5e2VkMKX5HB8MZ7TLBKkEy'},
#                                       {'key': 'neuron',
#                                        'value': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t'}],
#                        'type': 'cyberlink'},
#                       {'attributes': [{'key': 'action',
#                                        'value': '/cyber.graph.v1beta1.MsgCyberlink'},
#                                       {'key': 'module', 'value': 'graph'},
#                                       {'key': 'sender',
#                                        'value': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t'}],
#                        'type': 'message'}],
#            'events_by_type': {'cyberlink': {'neuron': ['bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t'],
#                                             'particleFrom': ['QmTYZZkRC8Kh4Uj3NhbMTbsHtn4GUFnKfMfKVU5BiMJHob'],
#                                             'particleTo': ['QmUveVbC1JdAJE4W53BwGFLJ5e2VkMKX5HB8MZ7TLBKkEy']},
#                               'message': {'action': ['/cyber.graph.v1beta1.MsgCyberlink'],
#                                           'module': ['graph'],
#                                           'sender': ['bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t']}},
#            'log': '',
#            'msg_index': 1},
#           {'events': [{'attributes': [{'key': 'particleFrom',
#                                        'value': 'QmTYZZkRC8Kh4Uj3NhbMTbsHtn4GUFnKfMfKVU5BiMJHob'},
#                                       {'key': 'particleTo',
#                                        'value': 'QmPWVLevpzEki6bcBF7bEk7rrNRhFSnBXD4imtTYM2pAgA'},
#                                       {'key': 'neuron',
#                                        'value': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t'}],
#                        'type': 'cyberlink'},
#                       {'attributes': [{'key': 'action',
#                                        'value': '/cyber.graph.v1beta1.MsgCyberlink'},
#                                       {'key': 'module', 'value': 'graph'},
#                                       {'key': 'sender',
#                                        'value': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t'}],
#                        'type': 'message'}],
#            'events_by_type': {'cyberlink': {'neuron': ['bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t'],
#                                             'particleFrom': ['QmTYZZkRC8Kh4Uj3NhbMTbsHtn4GUFnKfMfKVU5BiMJHob'],
#                                             'particleTo': ['QmPWVLevpzEki6bcBF7bEk7rrNRhFSnBXD4imtTYM2pAgA']},
#                               'message': {'action': ['/cyber.graph.v1beta1.MsgCyberlink'],
#                                           'module': ['graph'],
#                                           'sender': ['bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t']}},
#            'log': '',
#            'msg_index': 2},
#           {'events': [{'attributes': [{'key': 'particleFrom',
#                                        'value': 'QmTYZZkRC8Kh4Uj3NhbMTbsHtn4GUFnKfMfKVU5BiMJHob'},
#                                       {'key': 'particleTo',
#                                        'value': 'QmSpPA6mVdwq41xLBtgoHsi1ZrTn7DSi8kvNX9crhzDRFm'},
#                                       {'key': 'neuron',
#                                        'value': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t'}],
#                        'type': 'cyberlink'},
#                       {'attributes': [{'key': 'action',
#                                        'value': '/cyber.graph.v1beta1.MsgCyberlink'},
#                                       {'key': 'module', 'value': 'graph'},
#                                       {'key': 'sender',
#                                        'value': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t'}],
#                        'type': 'message'}],
#            'events_by_type': {'cyberlink': {'neuron': ['bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t'],
#                                             'particleFrom': ['QmTYZZkRC8Kh4Uj3NhbMTbsHtn4GUFnKfMfKVU5BiMJHob'],
#                                             'particleTo': ['QmSpPA6mVdwq41xLBtgoHsi1ZrTn7DSi8kvNX9crhzDRFm']},
#                               'message': {'action': ['/cyber.graph.v1beta1.MsgCyberlink'],
#                                           'module': ['graph'],
#                                           'sender': ['bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t']}},
#            'log': '',
#            'msg_index': 3},
#           {'events': [{'attributes': [{'key': 'particleFrom',
#                                        'value': 'QmTYZZkRC8Kh4Uj3NhbMTbsHtn4GUFnKfMfKVU5BiMJHob'},
#                                       {'key': 'particleTo',
#                                        'value': 'QmWWcKFcfXMNQGGUrymVMm973SudGmeLGeVsZGCoQQaG4r'},
#                                       {'key': 'neuron',
#                                        'value': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t'}],
#                        'type': 'cyberlink'},
#                       {'attributes': [{'key': 'action',
#                                        'value': '/cyber.graph.v1beta1.MsgCyberlink'},
#                                       {'key': 'module', 'value': 'graph'},
#                                       {'key': 'sender',
#                                        'value': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t'}],
#                        'type': 'message'}],
#            'events_by_type': {'cyberlink': {'neuron': ['bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t'],
#                                             'particleFrom': ['QmTYZZkRC8Kh4Uj3NhbMTbsHtn4GUFnKfMfKVU5BiMJHob'],
#                                             'particleTo': ['QmWWcKFcfXMNQGGUrymVMm973SudGmeLGeVsZGCoQQaG4r']},
#                               'message': {'action': ['/cyber.graph.v1beta1.MsgCyberlink'],
#                                           'module': ['graph'],
#                                           'sender': ['bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t']}},
#            'log': '',
#            'msg_index': 4},
#           {'events': [{'attributes': [{'key': 'particleFrom',
#                                        'value': 'QmTYZZkRC8Kh4Uj3NhbMTbsHtn4GUFnKfMfKVU5BiMJHob'},
#                                       {'key': 'particleTo',
#                                        'value': 'QmYgD5rDtUeYxJi1tRXMf1WVzDgByF3JtJeBZJjQk7atwv'},
#                                       {'key': 'neuron',
#                                        'value': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t'}],
#                        'type': 'cyberlink'},
#                       {'attributes': [{'key': 'action',
#                                        'value': '/cyber.graph.v1beta1.MsgCyberlink'},
#                                       {'key': 'module', 'value': 'graph'},
#                                       {'key': 'sender',
#                                        'value': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t'}],
#                        'type': 'message'}],
#            'events_by_type': {'cyberlink': {'neuron': ['bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t'],
#                                             'particleFrom': ['QmTYZZkRC8Kh4Uj3NhbMTbsHtn4GUFnKfMfKVU5BiMJHob'],
#                                             'particleTo': ['QmYgD5rDtUeYxJi1tRXMf1WVzDgByF3JtJeBZJjQk7atwv']},
#                               'message': {'action': ['/cyber.graph.v1beta1.MsgCyberlink'],
#                                           'module': ['graph'],
#                                           'sender': ['bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t']}},
#            'log': '',
#            'msg_index': 5},
#           {'events': [{'attributes': [{'key': 'particleFrom',
#                                        'value': 'QmTYZZkRC8Kh4Uj3NhbMTbsHtn4GUFnKfMfKVU5BiMJHob'},
#                                       {'key': 'particleTo',
#                                        'value': 'QmYVy5AGqrXXfS88dtMFavrQXKiYE4VYEKdcK3MSiwAwKJ'},
#                                       {'key': 'neuron',
#                                        'value': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t'}],
#                        'type': 'cyberlink'},
#                       {'attributes': [{'key': 'action',
#                                        'value': '/cyber.graph.v1beta1.MsgCyberlink'},
#                                       {'key': 'module', 'value': 'graph'},
#                                       {'key': 'sender',
#                                        'value': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t'}],
#                        'type': 'message'}],
#            'events_by_type': {'cyberlink': {'neuron': ['bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t'],
#                                             'particleFrom': ['QmTYZZkRC8Kh4Uj3NhbMTbsHtn4GUFnKfMfKVU5BiMJHob'],
#                                             'particleTo': ['QmYVy5AGqrXXfS88dtMFavrQXKiYE4VYEKdcK3MSiwAwKJ']},
#                               'message': {'action': ['/cyber.graph.v1beta1.MsgCyberlink'],
#                                           'module': ['graph'],
#                                           'sender': ['bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t']}},
#            'log': '',
#            'msg_index': 6},
#           {'events': [{'attributes': [{'key': 'particleFrom',
#                                        'value': 'QmTYZZkRC8Kh4Uj3NhbMTbsHtn4GUFnKfMfKVU5BiMJHob'},
#                                       {'key': 'particleTo',
#                                        'value': 'QmfUdg67cv5n8L5hzfhGNwepJYx9rG2Xb7Fi6AzMoP9Lp9'},
#                                       {'key': 'neuron',
#                                        'value': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t'}],
#                        'type': 'cyberlink'},
#                       {'attributes': [{'key': 'action',
#                                        'value': '/cyber.graph.v1beta1.MsgCyberlink'},
#                                       {'key': 'module', 'value': 'graph'},
#                                       {'key': 'sender',
#                                        'value': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t'}],
#                        'type': 'message'}],
#            'events_by_type': {'cyberlink': {'neuron': ['bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t'],
#                                             'particleFrom': ['QmTYZZkRC8Kh4Uj3NhbMTbsHtn4GUFnKfMfKVU5BiMJHob'],
#                                             'particleTo': ['QmfUdg67cv5n8L5hzfhGNwepJYx9rG2Xb7Fi6AzMoP9Lp9']},
#                               'message': {'action': ['/cyber.graph.v1beta1.MsgCyberlink'],
#                                           'module': ['graph'],
#                                           'sender': ['bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t']}},
#            'log': '',
#            'msg_index': 7},
#           {'events': [{'attributes': [{'key': 'particleFrom',
#                                        'value': 'QmTYZZkRC8Kh4Uj3NhbMTbsHtn4GUFnKfMfKVU5BiMJHob'},
#                                       {'key': 'particleTo',
#                                        'value': 'QmTG6hT74qhPfBr3U1dGQYmkZTTfPR3L4Cz9ZrJLLMyMff'},
#                                       {'key': 'neuron',
#                                        'value': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t'}],
#                        'type': 'cyberlink'},
#                       {'attributes': [{'key': 'action',
#                                        'value': '/cyber.graph.v1beta1.MsgCyberlink'},
#                                       {'key': 'module', 'value': 'graph'},
#                                       {'key': 'sender',
#                                        'value': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t'}],
#                        'type': 'message'}],
#            'events_by_type': {'cyberlink': {'neuron': ['bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t'],
#                                             'particleFrom': ['QmTYZZkRC8Kh4Uj3NhbMTbsHtn4GUFnKfMfKVU5BiMJHob'],
#                                             'particleTo': ['QmTG6hT74qhPfBr3U1dGQYmkZTTfPR3L4Cz9ZrJLLMyMff']},
#                               'message': {'action': ['/cyber.graph.v1beta1.MsgCyberlink'],
#                                           'module': ['graph'],
#                                           'sender': ['bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t']}},
#            'log': '',
#            'msg_index': 8},
#           {'events': [{'attributes': [{'key': 'particleFrom',
#                                        'value': 'QmTYZZkRC8Kh4Uj3NhbMTbsHtn4GUFnKfMfKVU5BiMJHob'},
#                                       {'key': 'particleTo',
#                                        'value': 'QmdL2cFkys7HUi2uonBS2hLMN5S4HG4RirRUAEaKjwp5Kf'},
#                                       {'key': 'neuron',
#                                        'value': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t'}],
#                        'type': 'cyberlink'},
#                       {'attributes': [{'key': 'action',
#                                        'value': '/cyber.graph.v1beta1.MsgCyberlink'},
#                                       {'key': 'module', 'value': 'graph'},
#                                       {'key': 'sender',
#                                        'value': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t'}],
#                        'type': 'message'}],
#            'events_by_type': {'cyberlink': {'neuron': ['bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t'],
#                                             'particleFrom': ['QmTYZZkRC8Kh4Uj3NhbMTbsHtn4GUFnKfMfKVU5BiMJHob'],
#                                             'particleTo': ['QmdL2cFkys7HUi2uonBS2hLMN5S4HG4RirRUAEaKjwp5Kf']},
#                               'message': {'action': ['/cyber.graph.v1beta1.MsgCyberlink'],
#                                           'module': ['graph'],
#                                           'sender': ['bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t']}},
#            'log': '',
#            'msg_index': 9},
#           {'events': [{'attributes': [{'key': 'particleFrom',
#                                        'value': 'QmTYZZkRC8Kh4Uj3NhbMTbsHtn4GUFnKfMfKVU5BiMJHob'},
#                                       {'key': 'particleTo',
#                                        'value': 'QmUKhiAPLh4mARTjM5PrnbuivtdEBYtDfYeyNcy2GeRWwB'},
#                                       {'key': 'neuron',
#                                        'value': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t'}],
#                        'type': 'cyberlink'},
#                       {'attributes': [{'key': 'action',
#                                        'value': '/cyber.graph.v1beta1.MsgCyberlink'},
#                                       {'key': 'module', 'value': 'graph'},
#                                       {'key': 'sender',
#                                        'value': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t'}],
#                        'type': 'message'}],
#            'events_by_type': {'cyberlink': {'neuron': ['bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t'],
#                                             'particleFrom': ['QmTYZZkRC8Kh4Uj3NhbMTbsHtn4GUFnKfMfKVU5BiMJHob'],
#                                             'particleTo': ['QmUKhiAPLh4mARTjM5PrnbuivtdEBYtDfYeyNcy2GeRWwB']},
#                               'message': {'action': ['/cyber.graph.v1beta1.MsgCyberlink'],
#                                           'module': ['graph'],
#                                           'sender': ['bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t']}},
#            'log': '',
#            'msg_index': 10},
#           {'events': [{'attributes': [{'key': 'particleFrom',
#                                        'value': 'QmTYZZkRC8Kh4Uj3NhbMTbsHtn4GUFnKfMfKVU5BiMJHob'},
#                                       {'key': 'particleTo',
#                                        'value': 'QmdeWidjcdp2BpVak6iwzpZYspsB6mJC9CZBVh5JTzkXDu'},
#                                       {'key': 'neuron',
#                                        'value': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t'}],
#                        'type': 'cyberlink'},
#                       {'attributes': [{'key': 'action',
#                                        'value': '/cyber.graph.v1beta1.MsgCyberlink'},
#                                       {'key': 'module', 'value': 'graph'},
#                                       {'key': 'sender',
#                                        'value': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t'}],
#                        'type': 'message'}],
#            'events_by_type': {'cyberlink': {'neuron': ['bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t'],
#                                             'particleFrom': ['QmTYZZkRC8Kh4Uj3NhbMTbsHtn4GUFnKfMfKVU5BiMJHob'],
#                                             'particleTo': ['Q

#           {'events': [{'attributes': [{'key': 'particleFrom',
#                                        'value': 'QmRBYkD21jJLB5nYc8FMWZWD9eSdt5mHBTUNuaihKzBHUU'},
#                                       {'key': 'particleTo',
#                                        'value': 'QmYVy5AGqrXXfS88dtMFavrQXKiYE4VYEKdcK3MSiwAwKJ'},
#                                       {'key': 'neuron',
#                                        'value': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t'}],
#                        'type': 'cyberlink'},
#                       {'attributes': [{'key': 'action',
#                                        'value': '/cyber.graph.v1beta1.MsgCyberlink'},
#                                       {'key': 'module', 'value': 'graph'},
#                                       {'key': 'sender',
#                                        'value': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t'}],
#                        'type': 'message'}],
#            'events_by_type': {'cyberlink': {'neuron': ['bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t'],
#                                             'particleFrom': ['QmRBYkD21jJLB5nYc8FMWZWD9eSdt5mHBTUNuaihKzBHUU'],
#                                             'particleTo': ['QmYVy5AGqrXXfS88dtMFavrQXKiYE4VYEKdcK3MSiwAwKJ']},
#                               'message': {'action': ['/cyber.graph.v1beta1.MsgCyberlink'],
#                                           'module': ['graph'],
#                                           'sender': ['bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t']}},
#            'log': '',
#            'msg_index': 47},
#           {'events': [{'attributes': [{'key': 'particleFrom',
#                                        'value': 'QmRBYkD21jJLB5nYc8FMWZWD9eSdt5mHBTUNuaihKzBHUU'},
#                                       {'key': 'particleTo',
#                                        'value': 'QmTG6hT74qhPfBr3U1dGQYmkZTTfPR3L4Cz9ZrJLLMyMff'},
#                                       {'key': 'neuron',
#                                        'value': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t'}],
#                        'type': 'cyberlink'},
#                       {'attributes': [{'key': 'action',
#                                        'value': '/cyber.graph.v1beta1.MsgCyberlink'},
#                                       {'key': 'module', 'value': 'graph'},
#                                       {'key': 'sender',
#                                        'value': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t'}],
#                        'type': 'message'}],
#            'events_by_type': {'cyberlink': {'neuron': ['bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t'],
#                                             'particleFrom': ['QmRBYkD21jJLB5nYc8FMWZWD9eSdt5mHBTUNuaihKzBHUU'],
#                                             'particleTo': ['QmTG6hT74qhPfBr3U1dGQYmkZTTfPR3L4Cz9ZrJLLMyMff']},
#                               'message': {'action': ['/cyber.graph.v1beta1.MsgCyberlink'],
#                                           'module': ['graph'],
#                                           'sender': ['bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t']}},
#            'log': '',
#            'msg_index': 48},
#           {'events': [{'attributes': [{'key': 'particleFrom',
#                                        'value': 'QmRBYkD21jJLB5nYc8FMWZWD9eSdt5mHBTUNuaihKzBHUU'},
#                                       {'key': 'particleTo',
#                                        'value': 'QmdL2cFkys7HUi2uonBS2hLMN5S4HG4RirRUAEaKjwp5Kf'},
#                                       {'key': 'neuron',
#                                        'value': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t'}],
#                        'type': 'cyberlink'},
#                       {'attributes': [{'key': 'action',
#                                        'value': '/cyber.graph.v1beta1.MsgCyberlink'},
#                                       {'key': 'module', 'value': 'graph'},
#                                       {'key': 'sender',
#                                        'value': 'bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t'}],
#                        'type': 'message'}],
#            'events_by_type': {'cyberlink': {'neuron': ['bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t'],
#                                             'particleFrom': ['QmRBYkD21jJLB5nYc8FMWZWD9eSdt5mHBTUNuaihKzBHUU'],
#                                             'particleTo': ['QmdL2cFkys7HUi2uonBS2hLMN5S4HG4RirRUAEaKjwp5Kf']},
#                               'message': {'action': ['/cyber.graph.v1beta1.MsgCyberlink'],
#                                           'module': ['graph'],
#                                           'sender': ['bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t']}},
#            'log': '',
#            'msg_index': 49}],
#  'raw_log': '[{"events":[{"type":"cyberlink","attributes":[{"key":"particleFrom","value":"QmVJmyPM3TvJBrjM8VhCQzr7cGhWSWsCVSeF4Rb9S8cMgh"},{"key":"particleTo","value":"QmSvZ7eA44GpT8spiJyo48FqwcrhV6Mufs1pid2t7gkgcE"},{"key":"neuron","value":"bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t"}]},{"type":"message","attributes":[{"key":"action","value":"/cyber.graph.v1beta1.MsgCyberlink"},{"key":"module","value":"graph"},{"key":"sender","value":"bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t"}]}]},{"msg_index":1,"events":[{"type":"cyberlink","attributes":[{"key":"particleFrom","value":"QmVJmyPM3TvJBrjM8VhCQzr7cGhWSWsCVSeF4Rb9S8cMgh"},{"key":"particleTo","value":"QmXe2QaSxXDWg4rgtoWoudjRuChF2bJ1Zw2C68DZT3s1TL"},{"key":"neuron","value":"bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t"}]},{"type":"message","attributes":[{"key":"action","value":"/cyber.graph.v1beta1.MsgCyberlink"},{"key":"module","value":"graph"},{"key":"sender","value":"bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t"}]}]},{"msg_index":2,"events":[{"type":"cyberlink","attributes":[{"key":"particleFrom","value":"QmVJmyPM3TvJBrjM8VhCQzr7cGhWSWsCVSeF4Rb9S8cMgh"},{"key":"particleTo","value":"QmWZg37xrZZcTuhvLocWexpuj7g9pShzP1RSjmyFj5QL5P"},{"key":"neuron","value":"bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t"}]},{"type":"message","attributes":[{"key":"action","value":"/cyber.graph.v1beta1.MsgCyberlink"},{"key":"module","value":"graph"},{"key":"sender","value":"bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t"}]}]},{"msg_index":3,"events":[{"type":"cyberlink","attributes":[{"key":"particleFrom","value":"QmVJmyPM3TvJBrjM8VhCQzr7cGhWSWsCVSeF4Rb9S8cMgh"},{"key":"particleTo","value":"QmSpPA6mVdwq41xLBtgoHsi1ZrTn7DSi8kvNX9crhzDRFm"},{"key":"neuron","value":"bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t"}]},{"type":"message","attributes":[{"key":"action","value":"/cyber.graph.v1beta1.MsgCyberlink"},{"key":"module","value":"graph"},{"key":"sender","value":"bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t"}]}]},{"msg_index":4,"events":[{"type":"cyberlink","attributes":[{"key":"particleFrom","value":"QmVJmyPM3TvJBrjM8VhCQzr7cGhWSWsCVSeF4Rb9S8cMgh"},{"key":"particleTo","value":"QmYgD5rDtUeYxJi1tRXMf1WVzDgByF3JtJeBZJjQk7atwv"},{"key":"neuron","value":"bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t"}]},{"type":"message","attributes":[{"key":"action","value":"/cyber.graph.v1beta1.MsgCyberlink"},{"key":"module","value":"graph"},{"key":"sender","value":"bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t"}]}]},{"msg_index":5,"events":[{"type":"cyberlink","attributes":[{"key":"particleFrom","value":"QmVJmyPM3TvJBrjM8VhCQzr7cGhWSWsCVSeF4Rb9S8cMgh"},{"key":"particleTo","value":"QmYdNqMojGRyqz3T41wrsRLLCeWj1ZQvxuaWkAruRRprM9"},{"key":"neuron","value":"bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t"}]},{"type":"message","attributes":[{"key":"action","value":"/cyber.graph.v1beta1.MsgCyberlink"},{"key":"module","value":"graph"},{"key":"sender","value":"bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t"}]}]},{"msg_index":6,"events":[{"type":"cyberlink","attributes":[{"key":"particleFrom","value":"QmVJmyPM3TvJBrjM8VhCQzr7cGhWSWsCVSeF4Rb9S8cMgh"},{"key":"particleTo","value":"QmYVy5AGqrXXfS88dtMFavrQXKiYE4VYEKdcK3MSiwAwKJ"},{"key":"neuron","value":"bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t"}]},{"type":"message","attributes":[{"key":"action","value":"/cyber.graph.v1beta1.MsgCyberlink"},{"key":"module","value":"graph"},{"key":"sender","value":"bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t"}]}]},{"msg_index":7,"events":[{"type":"cyberlink","attributes":[{"key":"particleFrom","value":"QmVJmyPM3TvJBrjM8VhCQzr7cGhWSWsCVSeF4Rb9S8cMgh"},{"key":"particleTo","value":"QmNYP6zeys9HN7R6HrwwWWHsPjhDW6qnFVACvxcUtER9Sp"},{"key":"neuron","value":"bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t"}]},{"type":"message","attributes":[{"key":"action","value":"/cyber.graph.v1beta1.MsgCyberlink"},{"key":"module","value":"graph"},{"key":"sender","value":"bostrom1cj8j6pc3nda8v708j3s4a6gq2jrnue7j857m9t"}]}]},{"msg_index":8,"events": ...
#  'timestamp': None,
#  'txhash': '7B3CBAC809B26BAC48C8CE98E0E00CD6C91C6D9389F94488108ACD10C4DDCA58'}
# {'code': 2,
#  'codespace': 'bandwidth',
#  'data': None,
#  'gas_used': 221172,
#  'gas_wanted': 2200000,
#  'height': 0,
#  'info': None,
#  'logs': None,
#  'raw_log': 'not enough personal bandwidth',
#  'timestamp': None,
#  'txhash': '54B413D5123940C6DFBA3EE56E72970921BB25FD0E9C663B433974DA4EB3417F'}
# {'code': 2,
#  'codespace': 'bandwidth',
#  'data': None,
#  'gas_used': 108952,
#  'gas_wanted': 1000000,
#  'height': 0,
#  'info': None,
#  'logs': None,
#  'raw_log': 'not enough personal bandwidth',
#  'timestamp': None,
#  'txhash': '1C3FB56DE75BDB56302A5822BE960F8EAB49F7BC7F1CA0788CBBB97BA4C0AC52'}
